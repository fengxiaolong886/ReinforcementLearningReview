# %%
"""
This code list implement the Monte Carlo Policy Gradient Alogrithm.
------------------------------------------------------------------
Input:
    differentiable policy function $\pi_{\theta}(a|s)$

Initalize:
    Parameter $\theta$ for policy function

Repeat  experience trajectory:
    Use $\pi_{\theta}(a|s)$ to generate one trajectory $(s_0,a_0,r_1....s_T)$
    Repeat each step in trajectory:
        G <--- cumlated reward at time step t
        Calculate the policy gradient  $\Delta\theta_t = \alpha \Delta_{\theta}log\pi_{\theta}(s_t, a_t)G_t$
------------------------------------------------------------------
"""
import time
import pandas as pd
import gym
import os 
import sys
import numpy as np
from collections import defaultdict, namedtuple
from keras.layers.core import Dense, Dropout, Activation
import keras.backend as K
from keras import models,layers,optimizers
from keras.utils import np_utils
import matplotlib
from matplotlib import pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
RENDER_ENV = False
LEARNING_RATE = 0.02
REWARD_DECAY = 0.99
OUTPUT_GRAPH = False
ENVNAME = "CartPole-v0"
HIDDEN_UNITS =[20, 20]
NUM_EPISODES = 200
ACTIVATION_FUNCTION = "tanh"

# %%
class MCPG():
    def __init__(self, 
                 n_action, 
                 n_feature, 
                 learning_rate=0.01, 
                 reward_decay=0.95, 
                 ouput_graph=False,
                ):
        self.n_action = n_action
        self.n_features = n_feature
        self.gamma = reward_decay
        self.learning_rate = learning_rate
        self.episode_observation = []
        self.episode_actions = [] 
        self.episode_rewards = []
        self.__build__network()
        self.__train_network()
        
        
    def __build__network(self):
        self.input_observation = layers.Input(shape=(self.n_features,))
        net = self.input_observation
        
        for h_dim in HIDDEN_UNITS:
            net = layers.Dense(h_dim)(net)
            net = layers.Activation(ACTIVATION_FUNCTION)(net)
            
        net = layers.Dense(self.n_action)(net)
        net = layers.Activation("softmax")(net)
        self.model = models.Model(inputs=self.input_observation, outputs=net)
        self.model.summary()
        
    def __train_network(self):
        action_prob_placeholder = self.model.output
        action_onehot_placeholder = K.placeholder(shape=(None, self.n_action),
                                                 name="action_onehot")
        discount_reward_placeholder = K.placeholder(shape=(None,),
                                                   name="discount_reward")
        action_prob = K.sum(action_prob_placeholder * action_onehot_placeholder, axis=1)
        log_action_prob = K.log(action_prob)
        
        loss = -log_action_prob*discount_reward_placeholder
        loss = K.mean(loss)
        
        adam = optimizers.Adam(lr=LEARNING_RATE)
        updates = adam.get_updates(params=self.model.trainable_weights,
                                    loss=loss)
        self.train_fn = K.function(inputs=[self.model.input,
                                          action_onehot_placeholder,
                                          discount_reward_placeholder],
                                   outputs=[self.model.output],
                                   updates=updates)
        
    def choose_action(self, observation):
        feed_state = observation[np.newaxis,:]
        prob_weights = self.model.predict(feed_state)
        action = np.random.choice(range(prob_weights.shape[1]),
                                 p=prob_weights.ravel())
        return action
    
    def store_transistion(self, s, a, r):
        self.episode_observation.append(s)
        self.episode_actions.append(a)
        self.episode_rewards.append(r)

    def learn(self):
        #discount and normalize the episode reward
        discounted_episode_reward_normalized = self._discount_and_norm_rewards()
        action_onehot = np_utils.to_categorical(self.episode_actions,
                                               num_classes=self.n_action)
        self.train_fn([np.vstack(self.episode_observation), action_onehot,
                       discounted_episode_reward_normalized])
        
        self.episode_observation = []
        self.episode_actions = [] 
        self.episode_rewards = []
        return discounted_episode_reward_normalized
    
    def _discount_and_norm_rewards(self):
        discounted_episode_reward = np.zeros_like(self.episode_rewards)
        running_add = 0
        for t in reversed(range(0, len(self.episode_rewards))):
            running_add = running_add * self.gamma + self.episode_rewards[t]
            discounted_episode_reward[t] = running_add
        
        # normalized
        discounted_episode_reward -= np.mean(discounted_episode_reward)
        discounted_episode_reward /= np.std(discounted_episode_reward)
        return discounted_episode_reward

# %%
def plot_episode_stats1(rec, xlabel, ylabel,title):
    fig = plt.figure(figsize=(20, 10), facecolor = "white")
    ax = fig.add_subplot(111)
    ax.plot(rec) 
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.set_title(title)
    return fig

def plot_episode_stats2(stats):
    # Plot time steps and episode number
    fig3 = plt.figure(figsize=(20, 10))
    plt.plot(np.cumsum(stats.episode_lengths), np.arange(len(stats.episode_lengths)))
    plt.xlabel("Time Steps")
    plt.ylabel("Episode")
    plt.title("Episode per time step")
    return fig3

def Plot_the_result(rec):
    # Plot episode length over time
    episode_lengths = rec.episode_lengths
    fig = plot_episode_stats1(episode_lengths, 
                       xlabel = "Episode",
                       ylabel = "Episode Length",
                       title = "Episode length over Time"
            )
    fig.show()
    fig.savefig("./log/MCPG_keras_CartPole_EpisodeLength.jpg")

    # Plot Episode reward over time
    smoohing_window = 10
    reward_smooths = pd.Series(rec.episode_rewards).rolling(smoohing_window,\
                    min_periods = smoohing_window).mean()
    fig = plot_episode_stats1(reward_smooths, 
                       xlabel = "Episode",
                       ylabel = "Episode Reward",
                       title = "Episode reward over time"
            )
    fig.show()
    fig.savefig("./log/MCPG_keras_CartPole_EpisodeReward.jpg")
    
    # Plot Episode per time step
    fig = plot_episode_stats2(rec)
    fig.show()
    fig.savefig("./log/MCPG_keras_CartPole_EpisodePerTimeStep.jpg")

# %%
def update(RL, env, num_episodes):
    # Track the statistics of the result
    record = namedtuple("Record", ["episode_lengths","episode_rewards"])
    
    rec = record(episode_lengths=np.zeros(num_episodes),
                          episode_rewards=np.zeros(num_episodes))
    
    for i_episode in range(num_episodes):
        if 0 == (i_episode +1) % 1:
            print("This the episode {}/{}".format(i_episode, num_episodes), end = "\r")
        observation = env.reset()
        step =0
        reward_cum = 0
        done = False
        while True:
            #env.render()
            if RENDER_ENV:
                env.render()
            # step1: choose action based on the state
            action = RL.choose_action(observation)
            # step2: take the action in the enviroment
            observation_next, reward, done, info = env.step(action)
            # step3: store the transistion for training
            RL.store_transistion(observation, action, reward)
            # update the record
            step += 1
#            if step % 10000 == 0:
#                print("step is:",step)
            rec.episode_lengths[i_episode] = step 
            rec.episode_rewards[i_episode] += reward
            if done or rec.episode_rewards[i_episode] > 2000:
                # step4: train the network
                RL.learn()
                print("The reward at episode {} is {}.".format(i_episode, 
                                                              rec.episode_rewards[i_episode]))
                break
            # step5: save the new state
            observation = observation_next
    print("Finished")
    env.close()
    return rec

# %%
if __name__ == "__main__":
    env = gym.make(ENVNAME)
    env = env.unwrapped
    RL = MCPG(n_action=env.action_space.n,
             n_feature=env.observation_space.shape[0],
             learning_rate=LEARNING_RATE,
             reward_decay=REWARD_DECAY,
             ouput_graph=OUTPUT_GRAPH)
    rec = update(RL, env, num_episodes=NUM_EPISODES)
    #Plot the result
    Plot_the_result(rec)
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 4)                 0
# _________________________________________________________________
# dense_1 (Dense)              (None, 20)                100
# _________________________________________________________________
# activation_1 (Activation)    (None, 20)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 20)                420
# _________________________________________________________________
# activation_2 (Activation)    (None, 20)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 42
# _________________________________________________________________
# activation_3 (Activation)    (None, 2)                 0
# =================================================================
# Total params: 562
# Trainable params: 562
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:From /home/jabes/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# The reward at episode 0 is 17.0.
# The reward at episode 1 is 13.0.
# The reward at episode 2 is 11.0.
# The reward at episode 3 is 12.0.
# The reward at episode 4 is 12.0.
# The reward at episode 5 is 12.0.
# The reward at episode 6 is 9.0.
# The reward at episode 7 is 10.0.
# The reward at episode 8 is 9.0.
# The reward at episode 9 is 12.0.
# The reward at episode 10 is 11.0.
# The reward at episode 11 is 10.0.
# The reward at episode 12 is 11.0.
# The reward at episode 13 is 10.0.
# The reward at episode 14 is 9.0.
# The reward at episode 15 is 9.0.
# The reward at episode 16 is 9.0.
# The reward at episode 17 is 9.0.
# The reward at episode 18 is 9.0.
# The reward at episode 19 is 9.0.
# The reward at episode 20 is 9.0.
# The reward at episode 21 is 9.0.
# The reward at episode 22 is 10.0.
# The reward at episode 23 is 11.0.
# The reward at episode 24 is 8.0.
# The reward at episode 25 is 8.0.
# The reward at episode 26 is 10.0.
# The reward at episode 27 is 10.0.
# The reward at episode 28 is 10.0.
# The reward at episode 29 is 11.0.
# The reward at episode 30 is 10.0.
# The reward at episode 31 is 8.0.
# The reward at episode 32 is 9.0.
# The reward at episode 33 is 9.0.
# The reward at episode 34 is 10.0.
# The reward at episode 35 is 10.0.
# The reward at episode 36 is 9.0.
# The reward at episode 37 is 12.0.
# The reward at episode 38 is 10.0.
# The reward at episode 39 is 9.0.
# The reward at episode 40 is 10.0.
# The reward at episode 41 is 10.0.
# The reward at episode 42 is 12.0.
# The reward at episode 43 is 10.0.
# The reward at episode 44 is 10.0.
# The reward at episode 45 is 9.0.
# The reward at episode 46 is 10.0.
# The reward at episode 47 is 10.0.
# The reward at episode 48 is 11.0.
# The reward at episode 49 is 9.0.
# The reward at episode 50 is 11.0.
# The reward at episode 51 is 10.0.
# The reward at episode 52 is 10.0.
# The reward at episode 53 is 9.0.
# The reward at episode 54 is 9.0.
# The reward at episode 55 is 10.0.
# The reward at episode 56 is 10.0.
# The reward at episode 57 is 10.0.
# The reward at episode 58 is 10.0.
# The reward at episode 59 is 9.0.
# The reward at episode 60 is 9.0.
# The reward at episode 61 is 10.0.
# The reward at episode 62 is 9.0.
# The reward at episode 63 is 9.0.
# The reward at episode 64 is 11.0.
# The reward at episode 65 is 9.0.
# The reward at episode 66 is 10.0.
# The reward at episode 67 is 10.0.
# The reward at episode 68 is 9.0.
# The reward at episode 69 is 10.0.
# The reward at episode 70 is 9.0.
# The reward at episode 71 is 10.0.
# The reward at episode 72 is 10.0.
# The reward at episode 73 is 10.0.
# The reward at episode 74 is 9.0.
# The reward at episode 75 is 10.0.
# The reward at episode 76 is 10.0.
# The reward at episode 77 is 10.0.
# The reward at episode 78 is 9.0.
# The reward at episode 79 is 9.0.
# The reward at episode 80 is 8.0.
# The reward at episode 81 is 8.0.
# The reward at episode 82 is 10.0.
# The reward at episode 83 is 10.0.
# The reward at episode 84 is 10.0.
# The reward at episode 85 is 10.0.
# The reward at episode 86 is 9.0.
# The reward at episode 87 is 10.0.
# The reward at episode 88 is 9.0.
# The reward at episode 89 is 10.0.
# The reward at episode 90 is 8.0.
# The reward at episode 91 is 9.0.
# The reward at episode 92 is 10.0.
# The reward at episode 93 is 9.0.
# The reward at episode 94 is 9.0.
# The reward at episode 95 is 10.0.
# The reward at episode 96 is 10.0.
# The reward at episode 97 is 10.0.
# The reward at episode 98 is 9.0.
# The reward at episode 99 is 10.0.
# The reward at episode 100 is 10.0.
# The reward at episode 101 is 9.0.
# The reward at episode 102 is 9.0.
# The reward at episode 103 is 9.0.
# The reward at episode 104 is 10.0.
# The reward at episode 105 is 9.0.
# The reward at episode 106 is 8.0.
# The reward at episode 107 is 9.0.
# The reward at episode 108 is 10.0.
# The reward at episode 109 is 10.0.
# The reward at episode 110 is 10.0.
# The reward at episode 111 is 9.0.
# The reward at episode 112 is 8.0.
# The reward at episode 113 is 10.0.
# The reward at episode 114 is 10.0.
# The reward at episode 115 is 9.0.
# The reward at episode 116 is 10.0.
# The reward at episode 117 is 9.0.
# The reward at episode 118 is 8.0.
# The reward at episode 119 is 10.0.
# The reward at episode 120 is 9.0.
# The reward at episode 121 is 10.0.
# The reward at episode 122 is 9.0.
# The reward at episode 123 is 9.0.
# The reward at episode 124 is 9.0.
# The reward at episode 125 is 10.0.
# The reward at episode 126 is 9.0.
# The reward at episode 127 is 10.0.
# The reward at episode 128 is 9.0.
# The reward at episode 129 is 8.0.
# The reward at episode 130 is 10.0.
# The reward at episode 131 is 10.0.
# The reward at episode 132 is 9.0.
# The reward at episode 133 is 8.0.
# The reward at episode 134 is 8.0.
# The reward at episode 135 is 10.0.
# The reward at episode 136 is 10.0.
# The reward at episode 137 is 10.0.
# The reward at episode 138 is 9.0.
# The reward at episode 139 is 10.0.
# The reward at episode 140 is 9.0.
# The reward at episode 141 is 9.0.
# The reward at episode 142 is 9.0.
# The reward at episode 143 is 10.0.
# The reward at episode 144 is 10.0.
# The reward at episode 145 is 8.0.
# The reward at episode 146 is 9.0.
# The reward at episode 147 is 9.0.
# The reward at episode 148 is 8.0.
# The reward at episode 149 is 9.0.
# The reward at episode 150 is 10.0.
# The reward at episode 151 is 10.0.
# The reward at episode 152 is 9.0.
# The reward at episode 153 is 10.0.
# The reward at episode 154 is 9.0.
# The reward at episode 155 is 9.0.
# The reward at episode 156 is 9.0.
# The reward at episode 157 is 9.0.
# The reward at episode 158 is 9.0.
# The reward at episode 159 is 10.0.
# The reward at episode 160 is 10.0.
# The reward at episode 161 is 9.0.
# The reward at episode 162 is 11.0.
# The reward at episode 163 is 9.0.
# The reward at episode 164 is 9.0.
# The reward at episode 165 is 10.0.
# The reward at episode 166 is 10.0.
# The reward at episode 167 is 10.0.
# The reward at episode 168 is 9.0.
# The reward at episode 169 is 9.0.
# The reward at episode 170 is 10.0.
# The reward at episode 171 is 10.0.
# The reward at episode 172 is 9.0.
# The reward at episode 173 is 9.0.
# The reward at episode 174 is 8.0.
# The reward at episode 175 is 8.0.
# The reward at episode 176 is 10.0.
# The reward at episode 177 is 10.0.
# The reward at episode 178 is 9.0.
# The reward at episode 179 is 9.0.
# The reward at episode 180 is 9.0.
# The reward at episode 181 is 10.0.
# The reward at episode 182 is 9.0.
# The reward at episode 183 is 9.0.
# The reward at episode 184 is 10.0.
# The reward at episode 185 is 10.0.
# The reward at episode 186 is 9.0.
# The reward at episode 187 is 9.0.
# The reward at episode 188 is 10.0.
# The reward at episode 189 is 9.0.
# The reward at episode 190 is 9.0.
# The reward at episode 191 is 10.0.
# The reward at episode 192 is 10.0.
# The reward at episode 193 is 9.0.
# The reward at episode 194 is 10.0.
# The reward at episode 195 is 9.0.
# The reward at episode 196 is 10.0.
# The reward at episode 197 is 9.0.
# The reward at episode 198 is 9.0.
# The reward at episode 199 is 9.0.
# Finished
# /home/jabes/.local/lib/python3.6/site-packages/ipykernel_launcher.py:27: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# /home/jabes/.local/lib/python3.6/site-packages/ipykernel_launcher.py:39: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# /home/jabes/.local/lib/python3.6/site-packages/ipykernel_launcher.py:44: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
