# %%
"""
This code list implement the Monte Carlo Policy Gradient Alogrithm.
------------------------------------------------------------------
Input:
    differentiable policy function $\pi_{\theta}(a|s)$

Initalize:
    Parameter $\theta$ for policy function

Repeat  experience trajectory:
    Use $\pi_{\theta}(a|s)$ to generate one trajectory $(s_0,a_0,r_1....s_T)$
    Repeat each step in trajectory:
        G <--- cumlated reward at time step t
        Calculate the policy gradient  $\Delta\theta_t = \alpha \Delta_{\theta}log\pi_{\theta}(s_t, a_t)G_t$
------------------------------------------------------------------
"""
import time
import pandas as pd
import gym
import os 
import sys
import numpy as np
from collections import defaultdict, namedtuple

import matplotlib
from matplotlib import pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.distributions import Bernoulli
from torch.autograd import Variable

# %%
RENDER_ENV = False
LEARNING_RATE = 0.02
REWARD_DECAY = 0.99
OUTPUT_GRAPH = False
ENVNAME = "CartPole-v0"
HIDDEN_UNITS =[20, 20]
NUM_EPISODES = 200

# %%
class Network(nn.Module):
    def __init__(self, n_features, n_action):
        super(Network, self).__init__()
        self.fc1 = nn.Linear(n_features, HIDDEN_UNITS[0])
        self.fc2 = nn.Linear(HIDDEN_UNITS[0], HIDDEN_UNITS[1])
        self.fc3 = nn.Linear(HIDDEN_UNITS[1], n_action)
    
    def forward(self, x):
        x = torch.tanh(self.fc1(x))
        x = torch.tanh(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
class MCPG():
    def __init__(self, 
                 n_action, 
                 n_feature, 
                 learning_rate=0.01, 
                 reward_decay=0.95, 
                 ouput_graph=False,
                ):
        self.n_action = n_action
        self.n_features = n_feature
        self.gamma = reward_decay
        self.learning_rate = learning_rate
        self.episode_observation = []
        self.episode_actions = [] 
        self.episode_rewards = []
        self.device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
        self.model = Network(self.n_features, self.n_action).to(self.device)
        self.optimizer = torch.optim.Adam(self.model.parameters(), lr=self.learning_rate)

    def choose_action(self, observation):
        state = torch.FloatTensor(observation).to(self.device)
        all_action_value = self.model.forward(state).to(self.device)
        prob_weights = F.softmax(all_action_value,dim=0)
        action_ = torch.distributions.Categorical(prob_weights)
        action = action_.sample().cpu().detach().item()
        return action
    
    def store_transistion(self, s, a, r):
        self.episode_observation.append(s)
        self.episode_actions.append(a)
        self.episode_rewards.append(r)

    def learn(self):
        discounted_episode_reward_normalized = self._discount_and_norm_rewards()
        
        tensor_states = torch.Tensor(np.vstack(self.episode_observation)).to(self.device)
        tensor_rewards = torch.Tensor(discounted_episode_reward_normalized).to(self.device)
        episode_size = len(self.episode_actions)
        tensor_actions=torch.LongTensor(self.episode_actions).reshape(episode_size,1).to(self.device)
        action_onehot = torch.FloatTensor(episode_size, self.n_action).to(self.device)
        action_onehot.zero_().to(self.device)
        action_onehot.scatter_(1, tensor_actions, 1).to(self.device)

        action_prob =  F.softmax(self.model.forward(tensor_states),dim=1).to(self.device)
        action_prob = torch.sum(action_prob * action_onehot, axis=1).to(self.device)
        log_action_prob = torch.log(action_prob).to(self.device)
        loss = -log_action_prob*tensor_rewards
        loss = torch.mean(loss)
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        self.episode_observation = []
        self.episode_actions = [] 
        self.episode_rewards = []
        return discounted_episode_reward_normalized
    
    def _discount_and_norm_rewards(self):
        discounted_episode_reward = np.zeros_like(self.episode_rewards)
        running_add = 0
        for t in reversed(range(0, len(self.episode_rewards))):
            running_add = running_add * self.gamma + self.episode_rewards[t]
            discounted_episode_reward[t] = running_add
        
        # normalized
        discounted_episode_reward -= np.mean(discounted_episode_reward)
        discounted_episode_reward /= np.std(discounted_episode_reward)
        return discounted_episode_reward

# %%
def plot_episode_stats1(rec, xlabel, ylabel,title):
    fig = plt.figure(figsize=(20, 10), facecolor = "white")
    ax = fig.add_subplot(111)
    ax.plot(rec) 
    ax.set_xlabel(xlabel)
    ax.set_ylabel(ylabel)
    ax.set_title(title)
    return fig

def plot_episode_stats2(stats):
    # Plot time steps and episode number
    fig3 = plt.figure(figsize=(20, 10))
    plt.plot(np.cumsum(stats.episode_lengths), np.arange(len(stats.episode_lengths)))
    plt.xlabel("Time Steps")
    plt.ylabel("Episode")
    plt.title("Episode per time step")
    return fig3

def Plot_the_result(rec):
    # Plot episode length over time
    episode_lengths = rec.episode_lengths
    fig = plot_episode_stats1(episode_lengths, 
                       xlabel = "Episode",
                       ylabel = "Episode Length",
                       title = "Episode length over Time"
            )
    fig.show()
    fig.savefig("./log/MCPG_pytorch_gpu_CartPole_EpisodeLength.jpg")

    # Plot Episode reward over time
    smoohing_window = 10
    reward_smooths = pd.Series(rec.episode_rewards).rolling(smoohing_window,\
                    min_periods = smoohing_window).mean()
    fig = plot_episode_stats1(reward_smooths, 
                       xlabel = "Episode",
                       ylabel = "Episode Reward",
                       title = "Episode reward over time"
            )
    fig.show()
    fig.savefig("./log/MCPG_pytorch_gpu_CartPole_EpisodeReward.jpg")
    
    # Plot Episode per time step
    fig = plot_episode_stats2(rec)
    fig.show()
    fig.savefig("./log/MCPG_pytorch_gpu_CartPole_EpisodePerTimeStep.jpg")

# %%
def update(RL, env, num_episodes):
    # Track the statistics of the result
    record = namedtuple("Record", ["episode_lengths","episode_rewards"])
    
    rec = record(episode_lengths=np.zeros(num_episodes),
                          episode_rewards=np.zeros(num_episodes))
    
    for i_episode in range(num_episodes):
        if 0 == (i_episode +1) % 1:
            print("This the episode {}/{}".format(i_episode, num_episodes), end = "\r")
        observation = env.reset()
        step =0
        reward_cum = 0
        done = False
        while True:
            #env.render()
            if RENDER_ENV:
                env.render()
            # step1: choose action based on the state
            action = RL.choose_action(observation)
            # step2: take the action in the enviroment
            observation_next, reward, done, info = env.step(action)
            # step3: store the transistion for training
            RL.store_transistion(observation, action, reward)
            # update the record
            step += 1
#            if step % 10000 == 0:
#                print("step is:",step)
            rec.episode_lengths[i_episode] = step 
            rec.episode_rewards[i_episode] += reward
            if done or rec.episode_rewards[i_episode] > 2000:
                # step4: train the network
                RL.learn()
                print("The reward at episode {} is {}.".format(i_episode, 
                                                              rec.episode_rewards[i_episode]))
                break
            # step5: save the new state
            observation = observation_next
    print("Finished")
    env.close()
    return rec

# %%
if __name__ == "__main__":
    env = gym.make(ENVNAME)
    env = env.unwrapped
    RL = MCPG(n_action=env.action_space.n,
             n_feature=env.observation_space.shape[0],
             learning_rate=LEARNING_RATE,
             reward_decay=REWARD_DECAY,
             ouput_graph=OUTPUT_GRAPH)
    rec = update(RL, env, num_episodes=NUM_EPISODES)
    #Plot the result
    Plot_the_result(rec)
# Out:
# The reward at episode 0 is 24.0.
# The reward at episode 1 is 19.0.
# The reward at episode 2 is 18.0.
# The reward at episode 3 is 17.0.
# The reward at episode 4 is 31.0.
# The reward at episode 5 is 12.0.
# The reward at episode 6 is 38.0.
# The reward at episode 7 is 15.0.
# The reward at episode 8 is 10.0.
# The reward at episode 9 is 23.0.
# The reward at episode 10 is 31.0.
# The reward at episode 11 is 17.0.
# The reward at episode 12 is 24.0.
# The reward at episode 13 is 16.0.
# The reward at episode 14 is 25.0.
# The reward at episode 15 is 24.0.
# The reward at episode 16 is 21.0.
# The reward at episode 17 is 21.0.
# The reward at episode 18 is 33.0.
# The reward at episode 19 is 19.0.
# The reward at episode 20 is 32.0.
# The reward at episode 21 is 13.0.
# The reward at episode 22 is 24.0.
# The reward at episode 23 is 18.0.
# The reward at episode 24 is 24.0.
# The reward at episode 25 is 43.0.
# The reward at episode 26 is 60.0.
# The reward at episode 27 is 55.0.
# The reward at episode 28 is 59.0.
# The reward at episode 29 is 63.0.
# The reward at episode 30 is 54.0.
# The reward at episode 31 is 42.0.
# The reward at episode 32 is 41.0.
# The reward at episode 33 is 45.0.
# The reward at episode 34 is 59.0.
# The reward at episode 35 is 60.0.
# The reward at episode 36 is 43.0.
# The reward at episode 37 is 36.0.
# The reward at episode 38 is 39.0.
# The reward at episode 39 is 26.0.
# The reward at episode 40 is 31.0.
# The reward at episode 41 is 25.0.
# The reward at episode 42 is 35.0.
# The reward at episode 43 is 34.0.
# The reward at episode 44 is 41.0.
# The reward at episode 45 is 36.0.
# The reward at episode 46 is 38.0.
# The reward at episode 47 is 28.0.
# The reward at episode 48 is 41.0.
# The reward at episode 49 is 70.0.
# The reward at episode 50 is 48.0.
# The reward at episode 51 is 45.0.
# The reward at episode 52 is 87.0.
# The reward at episode 53 is 48.0.
# The reward at episode 54 is 59.0.
# The reward at episode 55 is 83.0.
# The reward at episode 56 is 82.0.
# The reward at episode 57 is 67.0.
# The reward at episode 58 is 94.0.
# The reward at episode 59 is 282.0.
# The reward at episode 60 is 169.0.
# The reward at episode 61 is 324.0.
# The reward at episode 62 is 710.0.
# The reward at episode 63 is 454.0.
# The reward at episode 64 is 331.0.
# The reward at episode 65 is 475.0.
# The reward at episode 66 is 489.0.
# The reward at episode 67 is 343.0.
# The reward at episode 68 is 913.0.
# The reward at episode 69 is 1284.0.
# The reward at episode 70 is 2001.0.
# The reward at episode 71 is 2001.0.
# The reward at episode 72 is 2001.0.
# The reward at episode 73 is 884.0.
# The reward at episode 74 is 1625.0.
# The reward at episode 75 is 2001.0.
# The reward at episode 76 is 2001.0.
# The reward at episode 77 is 2001.0.
# The reward at episode 78 is 2001.0.
# The reward at episode 79 is 2001.0.
# The reward at episode 80 is 2001.0.
# The reward at episode 81 is 2001.0.
# The reward at episode 82 is 2001.0.
# The reward at episode 83 is 2001.0.
# The reward at episode 84 is 2001.0.
# The reward at episode 85 is 2001.0.
# The reward at episode 86 is 128.0.
# The reward at episode 87 is 2001.0.
# The reward at episode 88 is 2001.0.
# The reward at episode 89 is 2001.0.
# The reward at episode 90 is 2001.0.
# The reward at episode 91 is 837.0.
# The reward at episode 92 is 1484.0.
# The reward at episode 93 is 2001.0.
# The reward at episode 94 is 2001.0.
# The reward at episode 95 is 2001.0.
# The reward at episode 96 is 2001.0.
# The reward at episode 97 is 2001.0.
# The reward at episode 98 is 2001.0.
# The reward at episode 99 is 2001.0.
# The reward at episode 100 is 946.0.
# The reward at episode 101 is 900.0.
# The reward at episode 102 is 2001.0.
# The reward at episode 103 is 246.0.
# The reward at episode 104 is 561.0.
# The reward at episode 105 is 385.0.
# The reward at episode 106 is 446.0.
# The reward at episode 107 is 206.0.
# The reward at episode 108 is 399.0.
# The reward at episode 109 is 528.0.
# The reward at episode 110 is 358.0.
# The reward at episode 111 is 382.0.
# The reward at episode 112 is 313.0.
# The reward at episode 113 is 309.0.
# The reward at episode 114 is 227.0.
# The reward at episode 115 is 233.0.
# The reward at episode 116 is 473.0.
# The reward at episode 117 is 174.0.
# The reward at episode 118 is 234.0.
# The reward at episode 119 is 257.0.
# The reward at episode 120 is 227.0.
# The reward at episode 121 is 293.0.
# The reward at episode 122 is 161.0.
# The reward at episode 123 is 231.0.
# The reward at episode 124 is 453.0.
# The reward at episode 125 is 241.0.
# The reward at episode 126 is 235.0.
# The reward at episode 127 is 297.0.
# The reward at episode 128 is 435.0.
# The reward at episode 129 is 372.0.
# The reward at episode 130 is 911.0.
# The reward at episode 131 is 2001.0.
# The reward at episode 132 is 2001.0.
# The reward at episode 133 is 2001.0.
# The reward at episode 134 is 2001.0.
# The reward at episode 135 is 2001.0.
# The reward at episode 136 is 2001.0.
# The reward at episode 137 is 2001.0.
# The reward at episode 138 is 2001.0.
# The reward at episode 139 is 2001.0.
# The reward at episode 140 is 2001.0.
# The reward at episode 141 is 2001.0.
# The reward at episode 142 is 2001.0.
# The reward at episode 143 is 2001.0.
# The reward at episode 144 is 2001.0.
# The reward at episode 145 is 2001.0.
# The reward at episode 146 is 2001.0.
# The reward at episode 147 is 2001.0.
# The reward at episode 148 is 2001.0.
# The reward at episode 149 is 2001.0.
# The reward at episode 150 is 2001.0.
# The reward at episode 151 is 2001.0.
# The reward at episode 152 is 2001.0.
# The reward at episode 153 is 2001.0.
# The reward at episode 154 is 2001.0.
# The reward at episode 155 is 2001.0.
# The reward at episode 156 is 2001.0.
# The reward at episode 157 is 2001.0.
# The reward at episode 158 is 2001.0.
# The reward at episode 159 is 2001.0.
# The reward at episode 160 is 2001.0.
# The reward at episode 161 is 2001.0.
# The reward at episode 162 is 2001.0.
# The reward at episode 163 is 2001.0.
# The reward at episode 164 is 2001.0.
# The reward at episode 165 is 2001.0.
# The reward at episode 166 is 2001.0.
# The reward at episode 167 is 2001.0.
# The reward at episode 168 is 2001.0.
# The reward at episode 169 is 2001.0.
# The reward at episode 170 is 2001.0.
# The reward at episode 171 is 2001.0.
# The reward at episode 172 is 2001.0.
# The reward at episode 173 is 2001.0.
# The reward at episode 174 is 2001.0.
# The reward at episode 175 is 2001.0.
# The reward at episode 176 is 2001.0.
# The reward at episode 177 is 2001.0.
# The reward at episode 178 is 2001.0.
# The reward at episode 179 is 2001.0.
# The reward at episode 180 is 2001.0.
# The reward at episode 181 is 2001.0.
# The reward at episode 182 is 2001.0.
# The reward at episode 183 is 2001.0.
# The reward at episode 184 is 2001.0.
# The reward at episode 185 is 2001.0.
# The reward at episode 186 is 2001.0.
# The reward at episode 187 is 2001.0.
# The reward at episode 188 is 2001.0.
# The reward at episode 189 is 2001.0.
# The reward at episode 190 is 2001.0.
# The reward at episode 191 is 2001.0.
# The reward at episode 192 is 2001.0.
# The reward at episode 193 is 2001.0.
# The reward at episode 194 is 2001.0.
# The reward at episode 195 is 2001.0.
# The reward at episode 196 is 2001.0.
# The reward at episode 197 is 2001.0.
# The reward at episode 198 is 2001.0.
# The reward at episode 199 is 2001.0.
# Finished
# /home/jabes/.local/lib/python3.6/site-packages/ipykernel_launcher.py:27: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# /home/jabes/.local/lib/python3.6/site-packages/ipykernel_launcher.py:39: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# /home/jabes/.local/lib/python3.6/site-packages/ipykernel_launcher.py:44: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
